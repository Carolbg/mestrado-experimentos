# %%
# !pip3 install torch torchvision #cu110
# !rm -rf Codigos
#!pip install torch==1.7.0+cu110 torchvision==0.8.1+cu110 -f https://download.pytorch.org/whl/torch_stable.html

# %%
import torch
torch.cuda.is_available()

# %%
from google.colab import drive
drive.mount("/content/gdrive")

# %%
from ag_main import *

# %% [markdown]
# **Config 1** tm = 40

# %%
readData(False, 30)

# %%
population, populationFitness, model = main(20, 2, 80, 10, 40, False, 3,  True)

# %%
# %%capture
# !zip /content/surrogate_agDensenetHistoryPopulacaoFrontaisDoentesRun1Config1.zip /content/history*
# !zip /content/surrogate_agDensenetPlotsPopulacaoFrontaisDoentesRun1Config1.zip /content/plot*

# %%
population, populationFitness, model = main(20, 2, 80, 10, 40, False, 3,   True)

# %%
# %%capture
# !zip /content/surrogate_agDensenetHistoryPopulacaoFrontaisDoentesRun2Config1.zip /content/history*
# !zip /content/surrogate_agDensenetPlotsPopulacaoFrontaisDoentesRun2Config1.zip /content/plot*

# %%
population, populationFitness, model = main(20, 2, 80, 10, 40, False, 3,  True)

# %%
# %%capture
# !zip /content/surrogate_agDensenetHistoryPopulacaoFrontaisDoentesRun3Config1.zip /content/history*
# !zip /content/surrogate_agDensenetPlotsPopulacaoFrontaisDoentesRun3Config1.zip /content/plot*

# %%
population, populationFitness, model = main(20, 2, 80, 10, 40, False, 3,  True)

# %%
# %%capture
# !zip /content/surrogate_agDensenetHistoryPopulacaoFrontaisDoentesRun4Config1.zip /content/history*
# !zip /content/surrogate_agDensenetPlotsPopulacaoFrontaisDoentesRun4Config1.zip /content/plot*

# %%
population, populationFitness, model = main(20, 2, 80, 10, 40, False, 3,  True)

# %%
# %%capture
# !zip /content/surrogate_agDensenetHistoryPopulacaoFrontaisDoentesRun5Config1.zip /content/history*
# !zip /content/surrogate_agDensenetPlotsPopulacaoFrontaisDoentesRun5Config1.zip /content/plot*

# %%
# %%capture
# !zip /content/surrogate_agDensenetHistoryTestesPopulacaoConfig1.zip /content/surrogate_agDensenetHistory*
# !zip /content/surrogate_agDensenetPlotsTestesPopulacaoConfig1.zip /content/surrogate_agDensenetPlots*

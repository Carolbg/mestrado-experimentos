# %%
# !pip3 install torch torchvision #cu110
# !rm -rf Codigos
#!pip install torch==1.7.0+cu110 torchvision==0.8.1+cu110 -f https://download.pytorch.org/whl/torch_stable.html

# %%
import torch
torch.cuda.is_available()

# %%
from google.colab import drive
drive.mount("/content/gdrive")

# %%
from pso import *

# %%
readData(False, 30)

# %% [markdown]
# **Config 1**

# %%
#Densenet = 3
swarm = PSO(10, 10, 0.5, 3, True)

# %%
# %%capture
# !zip /content/Surrogate_PsoDensenetHistoryFrontaisConfig1Run1.zip /content/history*
# !zip /content/Surrogate_PsoDensenetPlotsFrontaisConfig1Run1.zip /content/plot*
# !zip /content/Surrogate_PsoDensenetSwarmFrontaisConfig1Run1.zip /content/swarm*

# %%
#Densenet = 3
swarm = PSO(10, 10, 0.5, 3, True)

# %%
# %%capture
# !zip /content/Surrogate_PsoDensenetHistoryFrontaisConfig1Run2.zip /content/history*
# !zip /content/Surrogate_PsoDensenetPlotsFrontaisConfig1Run2.zip /content/plot*
# !zip /content/Surrogate_PsoDensenetSwarmFrontaisConfig1Run2.zip /content/swarm*

# %%
#Densenet = 3
swarm = PSO(10, 10, 0.5, 3, True)

# %%
# %%capture
# !zip /content/Surrogate_PsoDensenetHistoryFrontaisConfig1Run3.zip /content/history*
# !zip /content/Surrogate_PsoDensenetPlotsFrontaisConfig1Run3.zip /content/plot*
# !zip /content/Surrogate_PsoDensenetSwarmFrontaisConfig1Run3.zip /content/swarm*

# %%
#Densenet = 3
swarm = PSO(10, 10, 0.5, 3, True)

# %%
# %%capture
# !zip /content/Surrogate_PsoDensenetHistoryFrontaisConfig1Run4.zip /content/history*
# !zip /content/Surrogate_PsoDensenetPlotsFrontaisConfig1Run4.zip /content/plot*
# !zip /content/Surrogate_PsoDensenetSwarmFrontaisConfig1Run4.zip /content/swarm*

# %%
#Densenet = 3
swarm = PSO(10, 10, 0.5, 3, True)

# %%
# %%capture
# !zip /content/Surrogate_PsoDensenetHistoryFrontaisConfig1Run5.zip /content/history*
# !zip /content/Surrogate_PsoDensenetPlotsFrontaisConfig1Run5.zip /content/plot*
# !zip /content/Surrogate_PsoDensenetSwarmFrontaisConfig1Run5.zip /content/swarm*

# %%
# !zip /content/Surrogate_PSODensenetHistoryFrontaisTestesPopulacaoConfig1.zip /content/Surrogate_PsoDensenetHistoryFrontaisConfig*
# !zip /content/Surrogate_PSODensenetPlotsFrontaisTestesPopulacaoConfig1.zip /content/Surrogate_PsoDensenetPlotsFrontaisConfig*
